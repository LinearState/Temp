# %%
from gensim.models import Word2Vec
import csv
from eunjeon import Mecab
import pandas as pd
import sys
import copy

mecab = Mecab()

# %%
#브랜드별 분류
def ext(data,brand):
    d=data[data['result']==brand]
    t=d['TEXT']
    return t
#명사 추출
def get_words(data):
    li=[]
    for i in data:
        w=mecab.nouns(i)
        li.append(w)
    # print(li)
    data=li
    return data
#word2vec 임베딩
def embedding(data):
    embedding_model = Word2Vec(data, size=100, window=2, min_count=50, iter=100, workers=2, sg=1)
    return embedding_model
#유사단어 검색
def check30(embedded,keyword):
    k=keyword
    temp=embedded.most_similar(k,topn=30)
    # print(temp)
    return temp
def check20(embedded,keyword):
    k=keyword
    temp=embedded.most_similar(positive=[k],topn=20)
    # print(temp)
    return temp
def pos_check10(embedded,keyword):
    k=keyword
    temp=embedded.most_similar(positive=[k],topn=10)
    print('[O]',k,'의 유사단어는 : ')
    print('    ',temp)
    return temp
def check10(embedded,keyword):
    k=keyword
    temp=embedded.most_similar(k,topn=10)
#     print('[X]',k,'의 유사단어는 : ')
#     print('    ',temp)
    return temp

# %%
data=pd.read_csv("resultDf3.csv",nrows=3042,index_col=0,encoding='cp949')

print("///브랜드별 분류 중...///")
all=data['TEXT']
naver=ext(data,'네이버')
kakao=ext(data,'카카오')
skt=ext(data,'SKT')
lg=ext(data,'LG')
kt=ext(data,'KT')

print("///브랜드별 명사 추출 중...///")
all = get_words(all)
naver = get_words(naver)
kakao = get_words(kakao)
skt = get_words(skt)
kt = get_words(kt)
lg = get_words(lg)

print("///추출된 단어로 word2vec 임베딩 중...///")
all_emb=embedding(all)
na_emb=embedding(naver)
ka_emb=embedding(kakao)
sk_emb=embedding(skt)
lg_emb=embedding(lg)
kt_emb=embedding(kt)
print(kt_emb)
# Out:
# ///브랜드별 분류 중...///
# ///브랜드별 단어 추출 중...///
# ///추출된 단어로 word2vec 임베딩 중...///
# Word2Vec(vocab=422, size=100, alpha=0.025)

# %%
rabelled_data=pd.read_csv('rabelled_words.csv',encoding='cp949',header=0)
print("///검색할 단어 목록 생성중...///")
key={'음성인식':[],
   '기타 편의기능':[],
   '앱-기기 연동':[],
   '디자인':[],
   '가격':[],
   '음악':[],
   '정보제공':[],
   '사운드':[],
   '휴대성':[]
   }

all_words=copy.deepcopy(key)
na_words=copy.deepcopy(key)
ka_words=copy.deepcopy(key)
sk_words=copy.deepcopy(key)
kt_words=copy.deepcopy(key)
lg_words=copy.deepcopy(key)

for i in range(len(rabelled_data)):
    categ=rabelled_data.iloc[i,0]
    words=rabelled_data.iloc[i,1]
    name=str(categ)
    key[name].append(words)

print("///검색할 단어 목록은 아래와 같음///")
for i in key :
    print(i)
    print(key[i])
# Out:
# ///검색할 단어 목록 생성중...///
# ///검색할 단어 목록은 아래와 같음///
# 음성인식
# ['음성인식', '누구', '기가지니', '인공지능', '지니', '기술', '대화', '부르', '이름', '말하', '명령어', '씽큐', '아리아', '대답', '마이크', '명령', '아리', '질문', '클로바', '클로바가', '클로바를', '헤이', '헤이카카오', '호출', '목소리', '알아듣', '클로버']
# 기타 편의기능
# ['기능', '가능', '가지', '서비스', '가능하다', '이야기', '이용', '필요', '가능한', '각종', '간편', '기능들', '기능들이', '도움', '동화', '등등', '라디오', '업그레이드', '유용', '제공하', '조절', '지원', '타이머', '탑재', '탑재한', '편리', '편리한', '편하', '노래방기', '놀랍', '이용해서', '탑재되']
# 앱-기기 연동
# ['연결', '스마트폰', '블루투스', '연동', '통하', '설정', '영상', '와이파이', '핸드폰', '공기청정기', '연동해', '디바이스', '리모컨', '메시지', '배달', '보내', '셋톱박스', '쇼핑', '스마트홈', '애플', '어플', '에어컨', '연결하면', '연결할', '연결해', '연결해서', '예약', '인터넷', '주문', '채널', '카카오톡', '카톡', '택시', '팟캐스트', '휴대폰', '무선', '설정할', '식자재마트', '아이폰', '연결하', '컨트롤', '티비']
# 디자인
# ['디자인', '버튼', '조명', '무드등', '박스', '새롭', '귀엽', '누르', '라이언', '보이', '피규어', '깔끔한', '라인', '모습', '본체', '불빛', '브라운', '심플한', '어디', '어울리', '어피치', '예쁘', '인테리어', '카카오프렌즈', '캐릭터', '프렌즈', '깔끔', '도라에몽', '무드', '분위기', '수유', '은은한', '화이트']
# 가격
# ['가격', '구매', '무료', '판매', '할인', '개월', '만원', '얼마', '저렴한', '저렴', '프리미엄', '환율']
# 음악
# ['노래', '음악', '멜론', '이용권', '뮤직', '스트리밍', '신나', '음원', '재생', '지니뮤직', '틀어달라고', '네이버뮤직']
# 정보제공
# ['알리', '날씨', '데이트', '시간', '오늘', '뉴스', '아침', '알람', '영어', '정보', '제공', '검색', '일정', '콘텐츠', '구글', '궁금한', '미세먼지', '설명', '실시간', '영화', '운세', '음식', '추천', '경기', '기사', '답변', '맞추', '오전', '정확']
# 사운드
# ['소리', '음질', '사운드', '들리', '볼륨', '오디오', '최대', '하만카돈']
# 휴대성
# ['배터리', '충전', '케이블', '충전기']

# %%
print("///검색 시작///")

datalist={'전체':all_emb,
          '네이버':na_emb,
          '카카오':ka_emb,
          'SKT':sk_emb,
          'KT':kt_emb,
          'LG':lg_emb
          }

df30=pd.DataFrame(columns=['brand','category','words','emotion'])
for brand, vector in datalist.items():
    print(brand,"탐색중...")
    if brand=='전체': b=0
    elif brand=='네이버': b=1
    elif brand=='카카오': b=2
    elif brand=='SKT' : b=3
    elif brand=='KT' : b=4
    elif brand=='LG' : b=5
    for category, words in key.items():
        cnt=0
        for w in words :
            print(category, ":", cnt, "번째 요소 :", w)
            if category=='디자인':c=0
            elif category=='가격':c=1
            elif category == '사운드':c = 2
            elif category == '휴대성':c=3
            elif category =='음성인식':c=4
            elif category =='앱-기기 연동':c=5
            elif category =='음악':c=6
            elif category =='정보제공':c=7
            elif category =='기타 편의기능':c=8
            df30=df30.append({
                "brand":b,
                "category":c,
                "words":w,
                "emotion":999
            },ignore_index=True)
            try:
                l=check30(vector,w)
                for i in l :
                    df30=df30.append({
                        "brand":b,
                        "category":c,
                        "words":i,
                        "emotion":999
                    },ignore_index=True)
            except Exception as ex:
                print('에러가 발생했습니다.',ex)
                pass
            cnt+=1
# df30.to_csv("brand_words_df30.csv",mode='w')
print(df30)
# Out:
# ///검색 시작///
# 전체 탐색중...
# 음성인식 : 0 번째 요소 : 음성인식
# 에러가 발생했습니다. "word '음성인식' not in vocabulary"
#
# 에러가 발생했습니다. "word '제공하' not in vocabulary"
# 기타 편의기능 : 20 번째 요소 : 조절
# 기타 편의기능 : 21 번째 요소 : 지원
# 기타 편의기능 : 22 번째 요소 : 타이머
# 에러가 발생했습니다. "word '타이머' not in vocabulary"
# 기타 편의기능 : 23 번째 요소 : 탑재
# 기타 편의기능 : 24 번째 요소 : 탑재한
# 에러가 발생했습니다. "word '탑재한' not in vocabulary"
# 기타 편의기능 : 25 번째 요소 : 편리
# 기타 편의기능 : 26 번째 요소 : 편리한
# 에러가 발생했습니다. "word '편리한' not in vocabulary"
# 기타 편의기능 : 27 번째 요소 : 편하
# 에러가 발생했습니다. "word '편하' not in vocabulary"
# 기타 편의기능 : 28 번째 요소 : 노래방기
# 에러가 발생했습니다. "word '노래방기' not in vocabulary"
# 기타 편의기능 : 29 번째 요소 : 놀랍
# 에러가 발생했습니다. "word '놀랍' not in vocabulary"
# 기타 편의기능 : 30 번째 요소 : 이용해서
# 에러가 발생했습니다. "word '이용해서' not in vocabulary"
# 기타 편의기능 : 31 번째 요소 : 탑재되
# 에러가 발생했습니다. "word '탑재되' not in vocabulary"
# 앱-기기 연동 : 0 번째 요소 : 연결
# 앱-기기 연동 : 1 번째 요소 : 스마트폰
# 앱-기기 연동 : 2 번째 요소 : 블루투스
# 앱-기기 연동 : 3 번째 요소 : 연동
# 앱-기기 연동 : 4 번째 요소 : 통하
# 에러가 발생했습니다. "word '통하' not in vocabulary"
# 앱-기기 연동 : 5 번째 요소 : 설정
# 앱-기기 연동 : 6 번째 요소 : 영상
# 앱-기기 연동 : 7 번째 요소 : 와이파이
# 앱-기기 연동 : 8 번째 요소 : 핸드폰
# 앱-기기 연동 : 9 번째 요소 : 공기청정기
# 에러가 발생했습니다. "word '공기청정기' not in vocabulary"
# 앱-기기 연동 : 10 번째 요소 : 연동해
# 에러가 발생했습니다. "word '연동해' not in vocabulary"
# 앱-기기 연동 : 11 번째 요소 : 디바이스
# 에러가 발생했습니다. "word '디바이스' not in vocabulary"
# 앱-기기 연동 : 12 번째 요소 : 리모컨
# 에러가 발생했습니다. "word '리모컨' not in vocabulary"
# 앱-기기 연동 : 13 번째 요소 : 메시지
# 에러가 발생했습니다. "word '메시지' not in vocabulary"
# 앱-기기 연동 : 14 번째 요소 : 배달
# 에러가 발생했습니다. "word '배달' not in vocabulary"
# 앱-기기 연동 : 15 번째 요소 : 보내
# 에러가 발생했습니다. "word '보내' not in vocabulary"
# 앱-기기 연동 : 16 번째 요소 : 셋톱박스
# 에러가 발생했습니다. "word '셋톱박스' not in vocabulary"
# 앱-기기 연동 : 17 번째 요소 : 쇼핑
# 에러가 발생했습니다. "word '쇼핑' not in vocabulary"
# 앱-기기 연동 : 18 번째 요소 : 스마트홈
# 에러가 발생했습니다. "word '스마트홈' not in vocabulary"
# 앱-기기 연동 : 19 번째 요소 : 애플
# 에러가 발생했습니다. "word '애플' not in vocabulary"
# 앱-기기 연동 : 20 번째 요소 : 어플
# 에러가 발생했습니다. "word '어플' not in vocabulary"
# 앱-기기 연동 : 21 번째 요소 : 에어컨
# 에러가 발생했습니다. "word '에어컨' not in vocabulary"
# 앱-기기 연동 : 22 번째 요소 : 연결하면
# 에러가 발생했습니다. "word '연결하면' not in vocabulary"
# 앱-기기 연동 : 23 번째 요소 : 연결할
# 에러가 발생했습니다. "word '연결할' not in vocabulary"
# 앱-기기 연동 : 24 번째 요소 : 연결해
# 에러가 발생했습니다. "word '연결해' not in vocabulary"
# 앱-기기 연동 : 25 번째 요소 : 연결해서
# 에러가 발생했습니다. "word '연결해서' not in vocabulary"
# 앱-기기 연동 : 26 번째 요소 : 예약
# 앱-기기 연동 : 27 번째 요소 : 인터넷
# 앱-기기 연동 : 28 번째 요소 : 주문
# 에러가 발생했습니다. "word '주문' not in vocabulary"
# 앱-기기 연동 : 29 번째 요소 : 채널
# 에러가 발생했습니다. "word '채널' not in vocabulary"
# 앱-기기 연동 : 30 번째 요소 : 카카오톡
# 앱-기기 연동 : 31 번째 요소 : 카톡
# 에러가 발생했습니다. "word '카톡' not in vocabulary"
# 앱-기기 연동 : 32 번째 요소 : 택시
# 에러가 발생했습니다. "word '택시' not in vocabulary"
# 앱-기기 연동 : 33 번째 요소 : 팟캐스트
# 에러가 발생했습니다. "word '팟캐스트' not in vocabulary"
# 앱-기기 연동 : 34 번째 요소 : 휴대폰
# 에러가 발생했습니다. "word '휴대폰' not in vocabulary"
# 앱-기기 연동 : 35 번째 요소 : 무선
# 에러가 발생했습니다. "word '무선' not in vocabulary"
# 앱-기기 연동 : 36 번째 요소 : 설정할
# 에러가 발생했습니다. "word '설정할' not in vocabulary"
# 앱-기기 연동 : 37 번째 요소 : 식자재마트
# 에러가 발생했습니다. "word '식자재마트' not in vocabulary"
# 앱-기기 연동 : 38 번째 요소 : 아이폰
# 에러가 발생했습니다. "word '아이폰' not in vocabulary"
# 앱-기기 연동 : 39 번째 요소 : 연결하
# 에러가 발생했습니다. "word '연결하' not in vocabulary"
# 앱-기기 연동 : 40 번째 요소 : 컨트롤
# 에러가 발생했습니다. "word '컨트롤' not in vocabulary"
# 앱-기기 연동 : 41 번째 요소 : 티비
# 에러가 발생했습니다. "word '티비' not in vocabulary"
# 디자인 : 0 번째 요소 : 디자인
# 디자인 : 1 번째 요소 : 버튼
# 디자인 : 2 번째 요소 : 조명
# 디자인 : 3 번째 요소 : 무드등
# 에러가 발생했습니다. "word '무드등' not in vocabulary"
# 디자인 : 4 번째 요소 : 박스
# 디자인 : 5 번째 요소 : 새롭
# 에러가 발생했습니다. "word '새롭' not in vocabulary"
# 디자인 : 6 번째 요소 : 귀엽
# 에러가 발생했습니다. "word '귀엽' not in vocabulary"
# 디자인 : 7 번째 요소 : 누르
# 에러가 발생했습니다. "word '누르' not in vocabulary"
# 디자인 : 8 번째 요소 : 라이언
# 에러가 발생했습니다. "word '라이언' not in vocabulary"
# 디자인 : 9 번째 요소 : 보이
# 에러가 발생했습니다. "word '보이' not in vocabulary"
# 디자인 : 10 번째 요소 : 피규어
# 에러가 발생했습니다. "word '피규어' not in vocabulary"
# 디자인 : 11 번째 요소 : 깔끔한
# 에러가 발생했습니다. "word '깔끔한' not in vocabulary"
# 디자인 : 12 번째 요소 : 라인
# 디자인 : 13 번째 요소 : 모습
# 디자인 : 14 번째 요소 : 본체
# 에러가 발생했습니다. "word '본체' not in vocabulary"
# 디자인 : 15 번째 요소 : 불빛
# 에러가 발생했습니다. "word '불빛' not in vocabulary"
# 디자인 : 16 번째 요소 : 브라운
# 디자인 : 17 번째 요소 : 심플한
# 에러가 발생했습니다. "word '심플한' not in vocabulary"
# 디자인 : 18 번째 요소 : 어디
# 디자인 : 19 번째 요소 : 어울리
# 에러가 발생했습니다. "word '어울리' not in vocabulary"
# 디자인 : 20 번째 요소 : 어피치
# 에러가 발생했습니다. "word '어피치' not in vocabulary"
# 디자인 : 21 번째 요소 : 예쁘
# 에러가 발생했습니다. "word '예쁘' not in vocabulary"
# 디자인 : 22 번째 요소 : 인테리어
# 에러가 발생했습니다. "word '인테리어' not in vocabulary"
# 디자인 : 23 번째 요소 : 카카오프렌즈
# 에러가 발생했습니다. "word '카카오프렌즈' not in vocabulary"
# 디자인 : 24 번째 요소 : 캐릭터
# 디자인 : 25 번째 요소 : 프렌즈
# 디자인 : 26 번째 요소 : 깔끔
# 에러가 발생했습니다. "word '깔끔' not in vocabulary"
# 디자인 : 27 번째 요소 : 도라에몽
# 에러가 발생했습니다. "word '도라에몽' not in vocabulary"
# 디자인 : 28 번째 요소 : 무드
# 에러가 발생했습니다. "word '무드' not in vocabulary"
# 디자인 : 29 번째 요소 : 분위기
# 에러가 발생했습니다. "word '분위기' not in vocabulary"
# 디자인 : 30 번째 요소 : 수유
# 에러가 발생했습니다. "word '수유' not in vocabulary"
# 디자인 : 31 번째 요소 : 은은한
# 에러가 발생했습니다. "word '은은한' not in vocabulary"
# 디자인 : 32 번째 요소 : 화이트
# 에러가 발생했습니다. "word '화이트' not in vocabulary"
# 가격 : 0 번째 요소 : 가격
# 가격 : 1 번째 요소 : 구매
# 가격 : 2 번째 요소 : 무료
# 에러가 발생했습니다. "word '무료' not in vocabulary"
# 가격 : 3 번째 요소 : 판매
# 가격 : 4 번째 요소 : 할인
# 에러가 발생했습니다. "word '할인' not in vocabulary"
# 가격 : 5 번째 요소 : 개월
# 에러가 발생했습니다. "word '개월' not in vocabulary"
# 가격 : 6 번째 요소 : 만원
# 에러가 발생했습니다. "word '만원' not in vocabulary"
# 가격 : 7 번째 요소 : 얼마
# 에러가 발생했습니다. "word '얼마' not in vocabulary"
# 가격 : 8 번째 요소 : 저렴한
# 에러가 발생했습니다. "word '저렴한' not in vocabulary"
# 가격 : 9 번째 요소 : 저렴
# 에러가 발생했습니다. "word '저렴' not in vocabulary"
# 가격 : 10 번째 요소 : 프리미엄
# 에러가 발생했습니다. "word '프리미엄' not in vocabulary"
# 가격 : 11 번째 요소 : 환율
# 에러가 발생했습니다. "word '환율' not in vocabulary"
# 음악 : 0 번째 요소 : 노래
# 음악 : 1 번째 요소 : 음악
# 음악 : 2 번째 요소 : 멜론
# 음악 : 3 번째 요소 : 이용권
# 에러가 발생했습니다. "word '이용권' not in vocabulary"
# 음악 : 4 번째 요소 : 뮤직
# 음악 : 5 번째 요소 : 스트리밍
# 에러가 발생했습니다. "word '스트리밍' not in vocabulary"
# 음악 : 6 번째 요소 : 신나
# 에러가 발생했습니다. "word '신나' not in vocabulary"
# 음악 : 7 번째 요소 : 음원
# 에러가 발생했습니다. "word '음원' not in vocabulary"
# 음악 : 8 번째 요소 : 재생
# 음악 : 9 번째 요소 : 지니뮤직
# 에러가 발생했습니다. "word '지니뮤직' not in vocabulary"
# 음악 : 10 번째 요소 : 틀어달라고
# 에러가 발생했습니다. "word '틀어달라고' not in vocabulary"
# 음악 : 11 번째 요소 : 네이버뮤직
# 에러가 발생했습니다. "word '네이버뮤직' not in vocabulary"
# 정보제공 : 0 번째 요소 : 알리
# 에러가 발생했습니다. "word '알리' not in vocabulary"
# 정보제공 : 1 번째 요소 : 날씨
# 정보제공 : 2 번째 요소 : 데이트
# 에러가 발생했습니다. "word '데이트' not in vocabulary"
# 정보제공 : 3 번째 요소 : 시간
# 정보제공 : 4 번째 요소 : 오늘
# 정보제공 : 5 번째 요소 : 뉴스
# 정보제공 : 6 번째 요소 : 아침
# 정보제공 : 7 번째 요소 : 알람
# 정보제공 : 8 번째 요소 : 영어
# 정보제공 : 9 번째 요소 : 정보
# 정보제공 : 10 번째 요소 : 제공
# 정보제공 : 11 번째 요소 : 검색
# 정보제공 : 12 번째 요소 : 일정
# 정보제공 : 13 번째 요소 : 콘텐츠
# 에러가 발생했습니다. "word '콘텐츠' not in vocabulary"
# 정보제공 : 14 번째 요소 : 구글
# 정보제공 : 15 번째 요소 : 궁금한
# 에러가 발생했습니다. "word '궁금한' not in vocabulary"
# 정보제공 : 16 번째 요소 : 미세먼지
# 에러가 발생했습니다. "word '미세먼지' not in vocabulary"
# 정보제공 : 17 번째 요소 : 설명
# 정보제공 : 18 번째 요소 : 실시간
# 에러가 발생했습니다. "word '실시간' not in vocabulary"
# 정보제공 : 19 번째 요소 : 영화
# 에러가 발생했습니다. "word '영화' not in vocabulary"
# 정보제공 : 20 번째 요소 : 운세
# 에러가 발생했습니다. "word '운세' not in vocabulary"
# 정보제공 : 21 번째 요소 : 음식
# 에러가 발생했습니다. "word '음식' not in vocabulary"
# 정보제공 : 22 번째 요소 : 추천
# 정보제공 : 23 번째 요소 : 경기
# 에러가 발생했습니다. "word '경기' not in vocabulary"
# 정보제공 : 24 번째 요소 : 기사
# 에러가 발생했습니다. "word '기사' not in vocabulary"
# 정보제공 : 25 번째 요소 : 답변
# 정보제공 : 26 번째 요소 : 맞추
# 에러가 발생했습니다. "word '맞추' not in vocabulary"
# 정보제공 : 27 번째 요소 : 오전
# 에러가 발생했습니다. "word '오전' not in vocabulary"
#
# 에러가 발생했습니다. "word '클로버' not in vocabulary"
# 기타 편의기능 : 0 번째 요소 : 기능
# 기타 편의기능 : 1 번째 요소 : 가능
# 기타 편의기능 : 2 번째 요소 : 가지
# 기타 편의기능 : 3 번째 요소 : 서비스
# 기타 편의기능 : 4 번째 요소 : 가능하다
# 에러가 발생했습니다. "word '가능하다' not in vocabulary"
# 기타 편의기능 : 5 번째 요소 : 이야기
# 기타 편의기능 : 6 번째 요소 : 이용
# 기타 편의기능 : 7 번째 요소 : 필요
# 기타 편의기능 : 8 번째 요소 : 가능한
# 에러가 발생했습니다. "word '가능한' not in vocabulary"
# 기타 편의기능 : 9 번째 요소 : 각종
# 기타 편의기능 : 10 번째 요소 : 간편
# 에러가 발생했습니다. "word '간편' not in vocabulary"
# 기타 편의기능 : 11 번째 요소 : 기능들
# 에러가 발생했습니다. "word '기능들' not in vocabulary"
# 기타 편의기능 : 12 번째 요소 : 기능들이
# 에러가 발생했습니다. "word '기능들이' not in vocabulary"
# 기타 편의기능 : 13 번째 요소 : 도움
# 기타 편의기능 : 14 번째 요소 : 동화
# 기타 편의기능 : 15 번째 요소 : 등등
# 기타 편의기능 : 16 번째 요소 : 라디오
# 기타 편의기능 : 17 번째 요소 : 업그레이드
# 기타 편의기능 : 18 번째 요소 : 유용
# 기타 편의기능 : 19 번째 요소 : 제공하
# 에러가 발생했습니다. "word '제공하' not in vocabulary"
# 기타 편의기능 : 20 번째 요소 : 조절
# 기타 편의기능 : 21 번째 요소 : 지원
# 기타 편의기능 : 22 번째 요소 : 타이머
# 에러가 발생했습니다. "word '타이머' not in vocabulary"
# 기타 편의기능 : 23 번째 요소 : 탑재
# 기타 편의기능 : 24 번째 요소 : 탑재한
# 에러가 발생했습니다. "word '탑재한' not in vocabulary"
# 기타 편의기능 : 25 번째 요소 : 편리
# 기타 편의기능 : 26 번째 요소 : 편리한
# 에러가 발생했습니다. "word '편리한' not in vocabulary"
# 기타 편의기능 : 27 번째 요소 : 편하
# 에러가 발생했습니다. "word '편하' not in vocabulary"
# 기타 편의기능 : 28 번째 요소 : 노래방기
# 에러가 발생했습니다. "word '노래방기' not in vocabulary"
# 기타 편의기능 : 29 번째 요소 : 놀랍
# 에러가 발생했습니다. "word '놀랍' not in vocabulary"
# 기타 편의기능 : 30 번째 요소 : 이용해서
# 에러가 발생했습니다. "word '이용해서' not in vocabulary"
# 기타 편의기능 : 31 번째 요소 : 탑재되
# 에러가 발생했습니다. "word '탑재되' not in vocabulary"
# 앱-기기 연동 : 0 번째 요소 : 연결
# 앱-기기 연동 : 1 번째 요소 : 스마트폰
# 앱-기기 연동 : 2 번째 요소 : 블루투스
# 앱-기기 연동 : 3 번째 요소 : 연동
# 앱-기기 연동 : 4 번째 요소 : 통하
# 에러가 발생했습니다. "word '통하' not in vocabulary"
# 앱-기기 연동 : 5 번째 요소 : 설정
# 앱-기기 연동 : 6 번째 요소 : 영상
# 앱-기기 연동 : 7 번째 요소 : 와이파이
# 앱-기기 연동 : 8 번째 요소 : 핸드폰
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-54ca73dab92a> in <module>()
#      46                         "words":i,
#      47                         "emotion":999
# ---> 48                     },ignore_index=True)
#      49             except Exception as ex:
#      50                 print('에러가 발생했습니다.',ex)
#
# c:\programdata\anaconda3\lib\site-packages\pandas\core\frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    6193             other = DataFrame(other.values.reshape((1, len(other))),
#    6194                               index=index,
# -> 6195                               columns=combined_columns)
#    6196             other = other._convert(datetime=True, timedelta=True)
#    6197             if not self.columns.equals(combined_columns):
#
# c:\programdata\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     377             else:
#     378                 mgr = self._init_ndarray(data, index, columns, dtype=dtype,
# --> 379                                          copy=copy)
#     380         elif isinstance(data, (list, types.GeneratorType)):
#     381             if isinstance(data, types.GeneratorType):
#
# c:\programdata\anaconda3\lib\site-packages\pandas\core\frame.py in _init_ndarray(self, values, index, columns, dtype, copy)
#     534             values = maybe_infer_to_datetimelike(values)
#     535
# --> 536         return create_block_manager_from_blocks([values], [columns, index])
#     537
#     538     @property
#
# c:\programdata\anaconda3\lib\site-packages\pandas\core\internals.py in create_block_manager_from_blocks(blocks, axes)
#    4857                                      placement=slice(0, len(axes[0])))]
#    4858
# -> 4859         mgr = BlockManager(blocks, axes)
#    4860         mgr._consolidate_inplace()
#    4861         return mgr
#
# c:\programdata\anaconda3\lib\site-packages\pandas\core\internals.py in __init__(self, blocks, axes, do_integrity_check)
#    3284         self._consolidate_check()
#    3285
# -> 3286         self._rebuild_blknos_and_blklocs()
#    3287
#    3288     def make_empty(self, axes=None):
#
# c:\programdata\anaconda3\lib\site-packages\pandas\core\internals.py in _rebuild_blknos_and_blklocs(self)
#    3373             rl = blk.mgr_locs
#    3374             new_blknos[rl.indexer] = blkno
# -> 3375             new_blklocs[rl.indexer] = np.arange(len(rl))
#    3376
#    3377         if (new_blknos == -1).any():
#
# KeyboardInterrupt:

# %%
df20=pd.DataFrame(columns=['brand','category','words','emotion'])
for brand, vector in datalist.items():
    print(brand,"탐색중...")
    if brand=='전체': b=0
    elif brand=='네이버': b=1
    elif brand=='카카오': b=2
    elif brand=='SKT' : b=3
    elif brand=='KT' : b=4
    elif brand=='LG' : b=5
    for category, words in key.items():
        cnt=0
        for i in words :
            print(category, ":", cnt, "번째 요소 :", i)
            if category=='디자인':c=0
            elif category=='가격':c=1
            elif category == '사운드':c = 2
            elif category == '휴대성':c=3
            elif category =='음성인식':c=4
            elif category =='앱-기기 연동':c=5
            elif category =='음악':c=6
            elif category =='정보제공':c=7
            elif category =='기타 편의기능':c=8
            try:
                l=check20(vector,i)
                for i in l :
                    df20=df20.append({
                        "brand":b,
                        "category":c,
                        "words":i,
                        "emotion":999
                    },ignore_index=True)
            except Exception as ex:
                print('에러가 발생했습니다.',ex)
                pass
            cnt+=1
df20.to_csv("brand_words_df20.csv",mode='w')

# %%
df10=pd.DataFrame(columns=['brand','category','words','emotion'])
for brand, vector in datalist.items():
#     print(brand,"탐색중...")
    if brand=='전체': b=0
    elif brand=='네이버': b=1
    elif brand=='카카오': b=2
    elif brand=='SKT' : b=3
    elif brand=='KT' : b=4
    elif brand=='LG' : b=5
    for category, words in key.items():
        cnt=0
        for w in words :
#             print(category, ":", cnt, "번째 요소 :", w)
            if category=='디자인':c=0
            elif category=='가격':c=1
            elif category == '사운드':c = 2
            elif category == '휴대성':c=3
            elif category =='음성인식':c=4
            elif category =='앱-기기 연동':c=5
            elif category =='음악':c=6
            elif category =='정보제공':c=7
            elif category =='기타 편의기능':c=8
            df10=df10.append({
                "brand":b,
                "category":c,
                "words":(w,1.0),
                "emotion":999
            },ignore_index=True)
            try:
                l=check10(vector,w)
                for i in l :
                    df10=df10.append({
                        "brand":b,
                        "category":c,
                        "words":i,
                        "emotion":999
                    },ignore_index=True)
            except Exception as ex:
                print('에러가 발생했습니다.',ex)
                pass
            cnt+=1
# df10.to_csv("brand_words_df10.csv",mode='w')
print(df10)
# Out:
# c:\programdata\anaconda3\lib\site-packages\ipykernel_launcher.py:38: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
# c:\programdata\anaconda3\lib\site-packages\gensim\matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int32 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# 에러가 발생했습니다. "word '음성인식' not in vocabulary"
# 에러가 발생했습니다. "word '기가지니' not in vocabulary"
# 에러가 발생했습니다. "word '부르' not in vocabulary"
# 에러가 발생했습니다. "word '말하' not in vocabulary"
# 에러가 발생했습니다. "word '씽큐' not in vocabulary"
# 에러가 발생했습니다. "word '클로바' not in vocabulary"
# 에러가 발생했습니다. "word '클로바가' not in vocabulary"
# 에러가 발생했습니다. "word '클로바를' not in vocabulary"
# 에러가 발생했습니다. "word '헤이카카오' not in vocabulary"
# 에러가 발생했습니다. "word '알아듣' not in vocabulary"
# 에러가 발생했습니다. "word '가능하다' not in vocabulary"
# 에러가 발생했습니다. "word '가능한' not in vocabulary"
# 에러가 발생했습니다. "word '간편' not in vocabulary"
# 에러가 발생했습니다. "word '기능들' not in vocabulary"
# 에러가 발생했습니다. "word '기능들이' not in vocabulary"
# 에러가 발생했습니다. "word '제공하' not in vocabulary"
# 에러가 발생했습니다. "word '탑재한' not in vocabulary"
# 에러가 발생했습니다. "word '편리한' not in vocabulary"
# 에러가 발생했습니다. "word '편하' not in vocabulary"
# 에러가 발생했습니다. "word '노래방기' not in vocabulary"
# 에러가 발생했습니다. "word '놀랍' not in vocabulary"
# 에러가 발생했습니다. "word '이용해서' not in vocabulary"
# 에러가 발생했습니다. "word '탑재되' not in vocabulary"
# 에러가 발생했습니다. "word '통하' not in vocabulary"
# 에러가 발생했습니다. "word '공기청정기' not in vocabulary"
# 에러가 발생했습니다. "word '연동해' not in vocabulary"
# 에러가 발생했습니다. "word '보내' not in vocabulary"
# 에러가 발생했습니다. "word '스마트홈' not in vocabulary"
# 에러가 발생했습니다. "word '어플' not in vocabulary"
# 에러가 발생했습니다. "word '연결하면' not in vocabulary"
# 에러가 발생했습니다. "word '연결할' not in vocabulary"
# 에러가 발생했습니다. "word '연결해' not in vocabulary"
# 에러가 발생했습니다. "word '연결해서' not in vocabulary"
# 에러가 발생했습니다. "word '설정할' not in vocabulary"
# 에러가 발생했습니다. "word '식자재마트' not in vocabulary"
# 에러가 발생했습니다. "word '연결하' not in vocabulary"
# 에러가 발생했습니다. "word '무드등' not in vocabulary"
# 에러가 발생했습니다. "word '새롭' not in vocabulary"
# 에러가 발생했습니다. "word '귀엽' not in vocabulary"
# 에러가 발생했습니다. "word '누르' not in vocabulary"
# 에러가 발생했습니다. "word '피규어' not in vocabulary"
# 에러가 발생했습니다. "word '깔끔한' not in vocabulary"
# 에러가 발생했습니다. "word '심플한' not in vocabulary"
# 에러가 발생했습니다. "word '어울리' not in vocabulary"
# 에러가 발생했습니다. "word '어피치' not in vocabulary"
# 에러가 발생했습니다. "word '예쁘' not in vocabulary"
# 에러가 발생했습니다. "word '카카오프렌즈' not in vocabulary"
# 에러가 발생했습니다. "word '깔끔' not in vocabulary"
# 에러가 발생했습니다. "word '은은한' not in vocabulary"
# 에러가 발생했습니다. "word '만원' not in vocabulary"
# 에러가 발생했습니다. "word '저렴한' not in vocabulary"
# 에러가 발생했습니다. "word '저렴' not in vocabulary"
# 에러가 발생했습니다. "word '신나' not in vocabulary"
# 에러가 발생했습니다. "word '지니뮤직' not in vocabulary"
# 에러가 발생했습니다. "word '틀어달라고' not in vocabulary"
# 에러가 발생했습니다. "word '네이버뮤직' not in vocabulary"
# 에러가 발생했습니다. "word '알리' not in vocabulary"
# 에러가 발생했습니다. "word '데이트' not in vocabulary"
# 에러가 발생했습니다. "word '궁금한' not in vocabulary"
# 에러가 발생했습니다. "word '맞추' not in vocabulary"
# 에러가 발생했습니다. "word '들리' not in vocabulary"
# 에러가 발생했습니다. "word '하만카돈' not in vocabulary"
# 에러가 발생했습니다. "word '음성인식' not in vocabulary"
# 에러가 발생했습니다. "word '기가지니' not in vocabulary"
# 에러가 발생했습니다. "word '지니' not in vocabulary"
# 에러가 발생했습니다. "word '부르' not in vocabulary"
# 에러가 발생했습니다. "word '말하' not in vocabulary"
# 에러가 발생했습니다. "word '씽큐' not in vocabulary"
# 에러가 발생했습니다. "word '아리아' not in vocabulary"
# 에러가 발생했습니다. "word '아리' not in vocabulary"
# 에러가 발생했습니다. "word '클로바' not in vocabulary"
# 에러가 발생했습니다. "word '클로바가' not in vocabulary"
# 에러가 발생했습니다. "word '클로바를' not in vocabulary"
# 에러가 발생했습니다. "word '헤이' not in vocabulary"
# 에러가 발생했습니다. "word '헤이카카오' not in vocabulary"
# 에러가 발생했습니다. "word '알아듣' not in vocabulary"
# 에러가 발생했습니다. "word '가능하다' not in vocabulary"
# 에러가 발생했습니다. "word '가능한' not in vocabulary"
# 에러가 발생했습니다. "word '각종' not in vocabulary"
# 에러가 발생했습니다. "word '간편' not in vocabulary"
# 에러가 발생했습니다. "word '기능들' not in vocabulary"
# 에러가 발생했습니다. "word '기능들이' not in vocabulary"
# 에러가 발생했습니다. "word '도움' not in vocabulary"
# 에러가 발생했습니다. "word '동화' not in vocabulary"
# 에러가 발생했습니다. "word '등등' not in vocabulary"
# 에러가 발생했습니다. "word '라디오' not in vocabulary"
# 에러가 발생했습니다. "word '업그레이드' not in vocabulary"
# 에러가 발생했습니다. "word '유용' not in vocabulary"
# 에러가 발생했습니다. "word '제공하' not in vocabulary"
# 에러가 발생했습니다. "word '타이머' not in vocabulary"
# 에러가 발생했습니다. "word '탑재한' not in vocabulary"
# 에러가 발생했습니다. "word '편리한' not in vocabulary"
# 에러가 발생했습니다. "word '편하' not in vocabulary"
# 에러가 발생했습니다. "word '노래방기' not in vocabulary"
# 에러가 발생했습니다. "word '놀랍' not in vocabulary"
# 에러가 발생했습니다. "word '이용해서' not in vocabulary"
# 에러가 발생했습니다. "word '탑재되' not in vocabulary"
# 에러가 발생했습니다. "word '통하' not in vocabulary"
# 에러가 발생했습니다. "word '공기청정기' not in vocabulary"
# 에러가 발생했습니다. "word '연동해' not in vocabulary"
# 에러가 발생했습니다. "word '디바이스' not in vocabulary"
# 에러가 발생했습니다. "word '리모컨' not in vocabulary"
# 에러가 발생했습니다. "word '메시지' not in vocabulary"
# 에러가 발생했습니다. "word '배달' not in vocabulary"
# 에러가 발생했습니다. "word '보내' not in vocabulary"
# 에러가 발생했습니다. "word '셋톱박스' not in vocabulary"
# 에러가 발생했습니다. "word '쇼핑' not in vocabulary"
# 에러가 발생했습니다. "word '스마트홈' not in vocabulary"
# 에러가 발생했습니다. "word '애플' not in vocabulary"
# 에러가 발생했습니다. "word '어플' not in vocabulary"
# 에러가 발생했습니다. "word '에어컨' not in vocabulary"
# 에러가 발생했습니다. "word '연결하면' not in vocabulary"
# 에러가 발생했습니다. "word '연결할' not in vocabulary"
# 에러가 발생했습니다. "word '연결해' not in vocabulary"
# 에러가 발생했습니다. "word '연결해서' not in vocabulary"
# 에러가 발생했습니다. "word '주문' not in vocabulary"
# 에러가 발생했습니다. "word '채널' not in vocabulary"
# 에러가 발생했습니다. "word '카톡' not in vocabulary"
# 에러가 발생했습니다. "word '택시' not in vocabulary"
# 에러가 발생했습니다. "word '팟캐스트' not in vocabulary"
# 에러가 발생했습니다. "word '휴대폰' not in vocabulary"
# 에러가 발생했습니다. "word '무선' not in vocabulary"
# 에러가 발생했습니다. "word '설정할' not in vocabulary"
# 에러가 발생했습니다. "word '식자재마트' not in vocabulary"
# 에러가 발생했습니다. "word '아이폰' not in vocabulary"
# 에러가 발생했습니다. "word '연결하' not in vocabulary"
# 에러가 발생했습니다. "word '컨트롤' not in vocabulary"
# 에러가 발생했습니다. "word '티비' not in vocabulary"
# 에러가 발생했습니다. "word '무드등' not in vocabulary"
# 에러가 발생했습니다. "word '새롭' not in vocabulary"
# 에러가 발생했습니다. "word '귀엽' not in vocabulary"
# 에러가 발생했습니다. "word '누르' not in vocabulary"
# 에러가 발생했습니다. "word '라이언' not in vocabulary"
# 에러가 발생했습니다. "word '보이' not in vocabulary"
# 에러가 발생했습니다. "word '피규어' not in vocabulary"
# 에러가 발생했습니다. "word '깔끔한' not in vocabulary"
# 에러가 발생했습니다. "word '본체' not in vocabulary"
# 에러가 발생했습니다. "word '불빛' not in vocabulary"
# 에러가 발생했습니다. "word '심플한' not in vocabulary"
# 에러가 발생했습니다. "word '어울리' not in vocabulary"
# 에러가 발생했습니다. "word '어피치' not in vocabulary"
# 에러가 발생했습니다. "word '예쁘' not in vocabulary"
# 에러가 발생했습니다. "word '인테리어' not in vocabulary"
# 에러가 발생했습니다. "word '카카오프렌즈' not in vocabulary"
# 에러가 발생했습니다. "word '깔끔' not in vocabulary"
# 에러가 발생했습니다. "word '도라에몽' not in vocabulary"
# 에러가 발생했습니다. "word '무드' not in vocabulary"
# 에러가 발생했습니다. "word '분위기' not in vocabulary"
# 에러가 발생했습니다. "word '수유' not in vocabulary"
# 에러가 발생했습니다. "word '은은한' not in vocabulary"
# 에러가 발생했습니다. "word '화이트' not in vocabulary"
# 에러가 발생했습니다. "word '무료' not in vocabulary"
# 에러가 발생했습니다. "word '할인' not in vocabulary"
# 에러가 발생했습니다. "word '개월' not in vocabulary"
# 에러가 발생했습니다. "word '만원' not in vocabulary"
# 에러가 발생했습니다. "word '얼마' not in vocabulary"
# 에러가 발생했습니다. "word '저렴한' not in vocabulary"
# 에러가 발생했습니다. "word '저렴' not in vocabulary"
# 에러가 발생했습니다. "word '프리미엄' not in vocabulary"
# 에러가 발생했습니다. "word '환율' not in vocabulary"
# 에러가 발생했습니다. "word '이용권' not in vocabulary"
# 에러가 발생했습니다. "word '스트리밍' not in vocabulary"
# 에러가 발생했습니다. "word '신나' not in vocabulary"
# 에러가 발생했습니다. "word '음원' not in vocabulary"
# 에러가 발생했습니다. "word '지니뮤직' not in vocabulary"
# 에러가 발생했습니다. "word '틀어달라고' not in vocabulary"
# 에러가 발생했습니다. "word '네이버뮤직' not in vocabulary"
# 에러가 발생했습니다. "word '알리' not in vocabulary"
# 에러가 발생했습니다. "word '데이트' not in vocabulary"
# 에러가 발생했습니다. "word '콘텐츠' not in vocabulary"
# 에러가 발생했습니다. "word '궁금한' not in vocabulary"
# 에러가 발생했습니다. "word '미세먼지' not in vocabulary"
# 에러가 발생했습니다. "word '실시간' not in vocabulary"
# 에러가 발생했습니다. "word '영화' not in vocabulary"
# 에러가 발생했습니다. "word '운세' not in vocabulary"
# 에러가 발생했습니다. "word '음식' not in vocabulary"
# 에러가 발생했습니다. "word '경기' not in vocabulary"
# 에러가 발생했습니다. "word '기사' not in vocabulary"
# 에러가 발생했습니다. "word '맞추' not in vocabulary"
# 에러가 발생했습니다. "word '오전' not in vocabulary"
# 에러가 발생했습니다. "word '정확' not in vocabulary"
# 에러가 발생했습니다. "word '들리' not in vocabulary"
# 에러가 발생했습니다. "word '오디오' not in vocabulary"
# 에러가 발생했습니다. "word '최대' not in vocabulary"
# 에러가 발생했습니다. "word '하만카돈' not in vocabulary"
# 에러가 발생했습니다. "word '음성인식' not in vocabulary"
# 에러가 발생했습니다. "word '기가지니' not in vocabulary"
# 에러가 발생했습니다. "word '부르' not in vocabulary"
# 에러가 발생했습니다. "word '말하' not in vocabulary"
# 에러가 발생했습니다. "word '씽큐' not in vocabulary"
# 에러가 발생했습니다. "word '아리' not in vocabulary"
# 에러가 발생했습니다. "word '클로바' not in vocabulary"
# 에러가 발생했습니다. "word '클로바가' not in vocabulary"
# 에러가 발생했습니다. "word '클로바를' not in vocabulary"
# 에러가 발생했습니다. "word '헤이카카오' not in vocabulary"
# 에러가 발생했습니다. "word '알아듣' not in vocabulary"
# 에러가 발생했습니다. "word '클로버' not in vocabulary"
# 에러가 발생했습니다. "word '가능하다' not in vocabulary"
# 에러가 발생했습니다. "word '가능한' not in vocabulary"
# 에러가 발생했습니다. "word '간편' not in vocabulary"
# 에러가 발생했습니다. "word '기능들' not in vocabulary"
# 에러가 발생했습니다. "word '기능들이' not in vocabulary"
# 에러가 발생했습니다. "word '제공하' not in vocabulary"
# 에러가 발생했습니다. "word '탑재한' not in vocabulary"
# 에러가 발생했습니다. "word '편리한' not in vocabulary"
# 에러가 발생했습니다. "word '편하' not in vocabulary"
# 에러가 발생했습니다. "word '노래방기' not in vocabulary"
# 에러가 발생했습니다. "word '놀랍' not in vocabulary"
# 에러가 발생했습니다. "word '이용해서' not in vocabulary"
# 에러가 발생했습니다. "word '탑재되' not in vocabulary"
# 에러가 발생했습니다. "word '통하' not in vocabulary"
# 에러가 발생했습니다. "word '공기청정기' not in vocabulary"
# 에러가 발생했습니다. "word '연동해' not in vocabulary"
# 에러가 발생했습니다. "word '보내' not in vocabulary"
# 에러가 발생했습니다. "word '셋톱박스' not in vocabulary"
# 에러가 발생했습니다. "word '스마트홈' not in vocabulary"
# 에러가 발생했습니다. "word '어플' not in vocabulary"
# 에러가 발생했습니다. "word '연결하면' not in vocabulary"
# 에러가 발생했습니다. "word '연결할' not in vocabulary"
# 에러가 발생했습니다. "word '연결해' not in vocabulary"
# 에러가 발생했습니다. "word '연결해서' not in vocabulary"
# 에러가 발생했습니다. "word '설정할' not in vocabulary"
# 에러가 발생했습니다. "word '식자재마트' not in vocabulary"
# 에러가 발생했습니다. "word '연결하' not in vocabulary"
# 에러가 발생했습니다. "word '무드등' not in vocabulary"
# 에러가 발생했습니다. "word '새롭' not in vocabulary"
# 에러가 발생했습니다. "word '귀엽' not in vocabulary"
# 에러가 발생했습니다. "word '누르' not in vocabulary"
# 에러가 발생했습니다. "word '보이' not in vocabulary"
# 에러가 발생했습니다. "word '피규어' not in vocabulary"
# 에러가 발생했습니다. "word '깔끔한' not in vocabulary"
# 에러가 발생했습니다. "word '심플한' not in vocabulary"
# 에러가 발생했습니다. "word '어울리' not in vocabulary"
# 에러가 발생했습니다. "word '어피치' not in vocabulary"
# 에러가 발생했습니다. "word '예쁘' not in vocabulary"
# 에러가 발생했습니다. "word '카카오프렌즈' not in vocabulary"
# 에러가 발생했습니다. "word '깔끔' not in vocabulary"
# 에러가 발생했습니다. "word '수유' not in vocabulary"
# 에러가 발생했습니다. "word '은은한' not in vocabulary"
# 에러가 발생했습니다. "word '화이트' not in vocabulary"
# 에러가 발생했습니다. "word '만원' not in vocabulary"
# 에러가 발생했습니다. "word '저렴한' not in vocabulary"
# 에러가 발생했습니다. "word '저렴' not in vocabulary"
# 에러가 발생했습니다. "word '프리미엄' not in vocabulary"
# 에러가 발생했습니다. "word '신나' not in vocabulary"
# 에러가 발생했습니다. "word '지니뮤직' not in vocabulary"
# 에러가 발생했습니다. "word '틀어달라고' not in vocabulary"
# 에러가 발생했습니다. "word '네이버뮤직' not in vocabulary"
# 에러가 발생했습니다. "word '알리' not in vocabulary"
# 에러가 발생했습니다. "word '데이트' not in vocabulary"
# 에러가 발생했습니다. "word '궁금한' not in vocabulary"
# 에러가 발생했습니다. "word '경기' not in vocabulary"
# 에러가 발생했습니다. "word '기사' not in vocabulary"
# 에러가 발생했습니다. "word '맞추' not in vocabulary"
# 에러가 발생했습니다. "word '들리' not in vocabulary"
# 에러가 발생했습니다. "word '하만카돈' not in vocabulary"
# 에러가 발생했습니다. "word '음성인식' not in vocabulary"
# 에러가 발생했습니다. "word '기가지니' not in vocabulary"
# 에러가 발생했습니다. "word '부르' not in vocabulary"
# 에러가 발생했습니다. "word '말하' not in vocabulary"
# 에러가 발생했습니다. "word '씽큐' not in vocabulary"
# 에러가 발생했습니다. "word '클로바' not in vocabulary"
# 에러가 발생했습니다. "word '클로바가' not in vocabulary"
# 에러가 발생했습니다. "word '클로바를' not in vocabulary"
# 에러가 발생했습니다. "word '헤이' not in vocabulary"
# 에러가 발생했습니다. "word '헤이카카오' not in vocabulary"
# 에러가 발생했습니다. "word '알아듣' not in vocabulary"
# 에러가 발생했습니다. "word '클로버' not in vocabulary"
# 에러가 발생했습니다. "word '가능하다' not in vocabulary"
# 에러가 발생했습니다. "word '가능한' not in vocabulary"
# 에러가 발생했습니다. "word '간편' not in vocabulary"
# 에러가 발생했습니다. "word '기능들' not in vocabulary"
# 에러가 발생했습니다. "word '기능들이' not in vocabulary"
# 에러가 발생했습니다. "word '제공하' not in vocabulary"
# 에러가 발생했습니다. "word '탑재한' not in vocabulary"
# 에러가 발생했습니다. "word '편리한' not in vocabulary"
# 에러가 발생했습니다. "word '편하' not in vocabulary"
# 에러가 발생했습니다. "word '노래방기' not in vocabulary"
# 에러가 발생했습니다. "word '놀랍' not in vocabulary"
# 에러가 발생했습니다. "word '이용해서' not in vocabulary"
# 에러가 발생했습니다. "word '탑재되' not in vocabulary"
# 에러가 발생했습니다. "word '통하' not in vocabulary"
# 에러가 발생했습니다. "word '공기청정기' not in vocabulary"
# 에러가 발생했습니다. "word '연동해' not in vocabulary"
# 에러가 발생했습니다. "word '보내' not in vocabulary"
# 에러가 발생했습니다. "word '스마트홈' not in vocabulary"
# 에러가 발생했습니다. "word '어플' not in vocabulary"
# 에러가 발생했습니다. "word '연결하면' not in vocabulary"
# 에러가 발생했습니다. "word '연결할' not in vocabulary"
# 에러가 발생했습니다. "word '연결해' not in vocabulary"
# 에러가 발생했습니다. "word '연결해서' not in vocabulary"
# 에러가 발생했습니다. "word '택시' not in vocabulary"
# 에러가 발생했습니다. "word '설정할' not in vocabulary"
# 에러가 발생했습니다. "word '식자재마트' not in vocabulary"
# 에러가 발생했습니다. "word '연결하' not in vocabulary"
# 에러가 발생했습니다. "word '무드등' not in vocabulary"
# 에러가 발생했습니다. "word '새롭' not in vocabulary"
# 에러가 발생했습니다. "word '귀엽' not in vocabulary"
# 에러가 발생했습니다. "word '누르' not in vocabulary"
# 에러가 발생했습니다. "word '라이언' not in vocabulary"
# 에러가 발생했습니다. "word '보이' not in vocabulary"
# 에러가 발생했습니다. "word '피규어' not in vocabulary"
# 에러가 발생했습니다. "word '깔끔한' not in vocabulary"
# 에러가 발생했습니다. "word '브라운' not in vocabulary"
# 에러가 발생했습니다. "word '심플한' not in vocabulary"
# 에러가 발생했습니다. "word '어울리' not in vocabulary"
# 에러가 발생했습니다. "word '어피치' not in vocabulary"
# 에러가 발생했습니다. "word '예쁘' not in vocabulary"
# 에러가 발생했습니다. "word '카카오프렌즈' not in vocabulary"
# 에러가 발생했습니다. "word '깔끔' not in vocabulary"
# 에러가 발생했습니다. "word '도라에몽' not in vocabulary"
# 에러가 발생했습니다. "word '은은한' not in vocabulary"
# 에러가 발생했습니다. "word '만원' not in vocabulary"
# 에러가 발생했습니다. "word '저렴한' not in vocabulary"
# 에러가 발생했습니다. "word '저렴' not in vocabulary"
# 에러가 발생했습니다. "word '환율' not in vocabulary"
# 에러가 발생했습니다. "word '신나' not in vocabulary"
# 에러가 발생했습니다. "word '지니뮤직' not in vocabulary"
# 에러가 발생했습니다. "word '틀어달라고' not in vocabulary"
# 에러가 발생했습니다. "word '네이버뮤직' not in vocabulary"
# 에러가 발생했습니다. "word '알리' not in vocabulary"
# 에러가 발생했습니다. "word '데이트' not in vocabulary"
# 에러가 발생했습니다. "word '궁금한' not in vocabulary"
# 에러가 발생했습니다. "word '맞추' not in vocabulary"
# 에러가 발생했습니다. "word '오전' not in vocabulary"
# 에러가 발생했습니다. "word '들리' not in vocabulary"
# 에러가 발생했습니다. "word '하만카돈' not in vocabulary"
# 에러가 발생했습니다. "word '음성인식' not in vocabulary"
# 에러가 발생했습니다. "word '기가지니' not in vocabulary"
# 에러가 발생했습니다. "word '부르' not in vocabulary"
# 에러가 발생했습니다. "word '말하' not in vocabulary"
# 에러가 발생했습니다. "word '씽큐' not in vocabulary"
# 에러가 발생했습니다. "word '아리아' not in vocabulary"
# 에러가 발생했습니다. "word '아리' not in vocabulary"
# 에러가 발생했습니다. "word '질문' not in vocabulary"
# 에러가 발생했습니다. "word '클로바' not in vocabulary"
# 에러가 발생했습니다. "word '클로바가' not in vocabulary"
# 에러가 발생했습니다. "word '클로바를' not in vocabulary"
# 에러가 발생했습니다. "word '헤이' not in vocabulary"
# 에러가 발생했습니다. "word '헤이카카오' not in vocabulary"
# 에러가 발생했습니다. "word '알아듣' not in vocabulary"
# 에러가 발생했습니다. "word '클로버' not in vocabulary"
# 에러가 발생했습니다. "word '가능하다' not in vocabulary"
# 에러가 발생했습니다. "word '가능한' not in vocabulary"
# 에러가 발생했습니다. "word '간편' not in vocabulary"
# 에러가 발생했습니다. "word '기능들' not in vocabulary"
# 에러가 발생했습니다. "word '기능들이' not in vocabulary"
# 에러가 발생했습니다. "word '제공하' not in vocabulary"
# 에러가 발생했습니다. "word '타이머' not in vocabulary"
# 에러가 발생했습니다. "word '탑재한' not in vocabulary"
# 에러가 발생했습니다. "word '편리한' not in vocabulary"
# 에러가 발생했습니다. "word '편하' not in vocabulary"
# 에러가 발생했습니다. "word '노래방기' not in vocabulary"
# 에러가 발생했습니다. "word '놀랍' not in vocabulary"
# 에러가 발생했습니다. "word '이용해서' not in vocabulary"
# 에러가 발생했습니다. "word '탑재되' not in vocabulary"
# 에러가 발생했습니다. "word '통하' not in vocabulary"
# 에러가 발생했습니다. "word '공기청정기' not in vocabulary"
# 에러가 발생했습니다. "word '연동해' not in vocabulary"
# 에러가 발생했습니다. "word '메시지' not in vocabulary"
# 에러가 발생했습니다. "word '보내' not in vocabulary"
# 에러가 발생했습니다. "word '스마트홈' not in vocabulary"
# 에러가 발생했습니다. "word '애플' not in vocabulary"
# 에러가 발생했습니다. "word '어플' not in vocabulary"
# 에러가 발생했습니다. "word '에어컨' not in vocabulary"
# 에러가 발생했습니다. "word '연결하면' not in vocabulary"
# 에러가 발생했습니다. "word '연결할' not in vocabulary"
# 에러가 발생했습니다. "word '연결해' not in vocabulary"
# 에러가 발생했습니다. "word '연결해서' not in vocabulary"
# 에러가 발생했습니다. "word '카카오톡' not in vocabulary"
# 에러가 발생했습니다. "word '카톡' not in vocabulary"
# 에러가 발생했습니다. "word '팟캐스트' not in vocabulary"
# 에러가 발생했습니다. "word '설정할' not in vocabulary"
# 에러가 발생했습니다. "word '식자재마트' not in vocabulary"
# 에러가 발생했습니다. "word '아이폰' not in vocabulary"
# 에러가 발생했습니다. "word '연결하' not in vocabulary"
# 에러가 발생했습니다. "word '무드등' not in vocabulary"
# 에러가 발생했습니다. "word '새롭' not in vocabulary"
# 에러가 발생했습니다. "word '귀엽' not in vocabulary"
# 에러가 발생했습니다. "word '누르' not in vocabulary"
# 에러가 발생했습니다. "word '라이언' not in vocabulary"
# 에러가 발생했습니다. "word '보이' not in vocabulary"
# 에러가 발생했습니다. "word '피규어' not in vocabulary"
# 에러가 발생했습니다. "word '깔끔한' not in vocabulary"
# 에러가 발생했습니다. "word '라인' not in vocabulary"
# 에러가 발생했습니다. "word '본체' not in vocabulary"
# 에러가 발생했습니다. "word '불빛' not in vocabulary"
# 에러가 발생했습니다. "word '심플한' not in vocabulary"
# 에러가 발생했습니다. "word '어울리' not in vocabulary"
# 에러가 발생했습니다. "word '어피치' not in vocabulary"
# 에러가 발생했습니다. "word '예쁘' not in vocabulary"
# 에러가 발생했습니다. "word '카카오프렌즈' not in vocabulary"
# 에러가 발생했습니다. "word '캐릭터' not in vocabulary"
# 에러가 발생했습니다. "word '깔끔' not in vocabulary"
# 에러가 발생했습니다. "word '도라에몽' not in vocabulary"
# 에러가 발생했습니다. "word '무드' not in vocabulary"
# 에러가 발생했습니다. "word '수유' not in vocabulary"
# 에러가 발생했습니다. "word '은은한' not in vocabulary"
# 에러가 발생했습니다. "word '만원' not in vocabulary"
# 에러가 발생했습니다. "word '저렴한' not in vocabulary"
# 에러가 발생했습니다. "word '저렴' not in vocabulary"
# 에러가 발생했습니다. "word '환율' not in vocabulary"
# 에러가 발생했습니다. "word '이용권' not in vocabulary"
# 에러가 발생했습니다. "word '신나' not in vocabulary"
# 에러가 발생했습니다. "word '지니뮤직' not in vocabulary"
# 에러가 발생했습니다. "word '틀어달라고' not in vocabulary"
# 에러가 발생했습니다. "word '네이버뮤직' not in vocabulary"
# 에러가 발생했습니다. "word '알리' not in vocabulary"
# 에러가 발생했습니다. "word '데이트' not in vocabulary"
# 에러가 발생했습니다. "word '궁금한' not in vocabulary"
# 에러가 발생했습니다. "word '미세먼지' not in vocabulary"
# 에러가 발생했습니다. "word '운세' not in vocabulary"
# 에러가 발생했습니다. "word '경기' not in vocabulary"
# 에러가 발생했습니다. "word '답변' not in vocabulary"
# 에러가 발생했습니다. "word '맞추' not in vocabulary"
# 에러가 발생했습니다. "word '오전' not in vocabulary"
# 에러가 발생했습니다. "word '정확' not in vocabulary"
# 에러가 발생했습니다. "word '들리' not in vocabulary"
# 에러가 발생했습니다. "word '하만카돈' not in vocabulary"
# 에러가 발생했습니다. "word '충전기' not in vocabulary"
# 에러가 발생했습니다. "word '음성인식' not in vocabulary"
# 에러가 발생했습니다. "word '누구' not in vocabulary"
# 에러가 발생했습니다. "word '기가지니' not in vocabulary"
# 에러가 발생했습니다. "word '지니' not in vocabulary"
# 에러가 발생했습니다. "word '부르' not in vocabulary"
# 에러가 발생했습니다. "word '이름' not in vocabulary"
# 에러가 발생했습니다. "word '말하' not in vocabulary"
# 에러가 발생했습니다. "word '명령어' not in vocabulary"
# 에러가 발생했습니다. "word '씽큐' not in vocabulary"
# 에러가 발생했습니다. "word '아리아' not in vocabulary"
# 에러가 발생했습니다. "word '대답' not in vocabulary"
# 에러가 발생했습니다. "word '마이크' not in vocabulary"
# 에러가 발생했습니다. "word '아리' not in vocabulary"
# 에러가 발생했습니다. "word '질문' not in vocabulary"
# 에러가 발생했습니다. "word '클로바' not in vocabulary"
# 에러가 발생했습니다. "word '클로바가' not in vocabulary"
# 에러가 발생했습니다. "word '클로바를' not in vocabulary"
# 에러가 발생했습니다. "word '헤이' not in vocabulary"
# 에러가 발생했습니다. "word '헤이카카오' not in vocabulary"
# 에러가 발생했습니다. "word '호출' not in vocabulary"
# 에러가 발생했습니다. "word '목소리' not in vocabulary"
# 에러가 발생했습니다. "word '알아듣' not in vocabulary"
# 에러가 발생했습니다. "word '클로버' not in vocabulary"
# 에러가 발생했습니다. "word '가능하다' not in vocabulary"
# 에러가 발생했습니다. "word '이야기' not in vocabulary"
# 에러가 발생했습니다. "word '가능한' not in vocabulary"
# 에러가 발생했습니다. "word '각종' not in vocabulary"
# 에러가 발생했습니다. "word '간편' not in vocabulary"
# 에러가 발생했습니다. "word '기능들' not in vocabulary"
# 에러가 발생했습니다. "word '기능들이' not in vocabulary"
# 에러가 발생했습니다. "word '도움' not in vocabulary"
# 에러가 발생했습니다. "word '동화' not in vocabulary"
# 에러가 발생했습니다. "word '등등' not in vocabulary"
# 에러가 발생했습니다. "word '라디오' not in vocabulary"
# 에러가 발생했습니다. "word '업그레이드' not in vocabulary"
# 에러가 발생했습니다. "word '유용' not in vocabulary"
# 에러가 발생했습니다. "word '제공하' not in vocabulary"
# 에러가 발생했습니다. "word '조절' not in vocabulary"
# 에러가 발생했습니다. "word '탑재한' not in vocabulary"
# 에러가 발생했습니다. "word '편리한' not in vocabulary"
# 에러가 발생했습니다. "word '편하' not in vocabulary"
# 에러가 발생했습니다. "word '노래방기' not in vocabulary"
# 에러가 발생했습니다. "word '놀랍' not in vocabulary"
# 에러가 발생했습니다. "word '이용해서' not in vocabulary"
# 에러가 발생했습니다. "word '탑재되' not in vocabulary"
# 에러가 발생했습니다. "word '통하' not in vocabulary"
# 에러가 발생했습니다. "word '영상' not in vocabulary"
# 에러가 발생했습니다. "word '와이파이' not in vocabulary"
# 에러가 발생했습니다. "word '핸드폰' not in vocabulary"
# 에러가 발생했습니다. "word '공기청정기' not in vocabulary"
# 에러가 발생했습니다. "word '연동해' not in vocabulary"
# 에러가 발생했습니다. "word '리모컨' not in vocabulary"
# 에러가 발생했습니다. "word '메시지' not in vocabulary"
# 에러가 발생했습니다. "word '배달' not in vocabulary"
# 에러가 발생했습니다. "word '보내' not in vocabulary"
# 에러가 발생했습니다. "word '셋톱박스' not in vocabulary"
# 에러가 발생했습니다. "word '쇼핑' not in vocabulary"
# 에러가 발생했습니다. "word '스마트홈' not in vocabulary"
# 에러가 발생했습니다. "word '어플' not in vocabulary"
# 에러가 발생했습니다. "word '연결하면' not in vocabulary"
# 에러가 발생했습니다. "word '연결할' not in vocabulary"
# 에러가 발생했습니다. "word '연결해' not in vocabulary"
# 에러가 발생했습니다. "word '연결해서' not in vocabulary"
# 에러가 발생했습니다. "word '예약' not in vocabulary"
# 에러가 발생했습니다. "word '주문' not in vocabulary"
# 에러가 발생했습니다. "word '채널' not in vocabulary"
# 에러가 발생했습니다. "word '카카오톡' not in vocabulary"
# 에러가 발생했습니다. "word '카톡' not in vocabulary"
# 에러가 발생했습니다. "word '택시' not in vocabulary"
# 에러가 발생했습니다. "word '팟캐스트' not in vocabulary"
# 에러가 발생했습니다. "word '휴대폰' not in vocabulary"
# 에러가 발생했습니다. "word '무선' not in vocabulary"
# 에러가 발생했습니다. "word '설정할' not in vocabulary"
# 에러가 발생했습니다. "word '식자재마트' not in vocabulary"
# 에러가 발생했습니다. "word '아이폰' not in vocabulary"
# 에러가 발생했습니다. "word '연결하' not in vocabulary"
# 에러가 발생했습니다. "word '컨트롤' not in vocabulary"
# 에러가 발생했습니다. "word '티비' not in vocabulary"
# 에러가 발생했습니다. "word '디자인' not in vocabulary"
# 에러가 발생했습니다. "word '조명' not in vocabulary"
# 에러가 발생했습니다. "word '무드등' not in vocabulary"
# 에러가 발생했습니다. "word '박스' not in vocabulary"
# 에러가 발생했습니다. "word '새롭' not in vocabulary"
# 에러가 발생했습니다. "word '귀엽' not in vocabulary"
# 에러가 발생했습니다. "word '누르' not in vocabulary"
# 에러가 발생했습니다. "word '라이언' not in vocabulary"
# 에러가 발생했습니다. "word '보이' not in vocabulary"
# 에러가 발생했습니다. "word '피규어' not in vocabulary"
# 에러가 발생했습니다. "word '깔끔한' not in vocabulary"
# 에러가 발생했습니다. "word '라인' not in vocabulary"
# 에러가 발생했습니다. "word '본체' not in vocabulary"
# 에러가 발생했습니다. "word '불빛' not in vocabulary"
# 에러가 발생했습니다. "word '브라운' not in vocabulary"
# 에러가 발생했습니다. "word '심플한' not in vocabulary"
# 에러가 발생했습니다. "word '어디' not in vocabulary"
# 에러가 발생했습니다. "word '어울리' not in vocabulary"
# 에러가 발생했습니다. "word '어피치' not in vocabulary"
# 에러가 발생했습니다. "word '예쁘' not in vocabulary"
# 에러가 발생했습니다. "word '인테리어' not in vocabulary"
# 에러가 발생했습니다. "word '카카오프렌즈' not in vocabulary"
# 에러가 발생했습니다. "word '캐릭터' not in vocabulary"
# 에러가 발생했습니다. "word '프렌즈' not in vocabulary"
# 에러가 발생했습니다. "word '깔끔' not in vocabulary"
# 에러가 발생했습니다. "word '도라에몽' not in vocabulary"
# 에러가 발생했습니다. "word '무드' not in vocabulary"
# 에러가 발생했습니다. "word '분위기' not in vocabulary"
# 에러가 발생했습니다. "word '수유' not in vocabulary"
# 에러가 발생했습니다. "word '은은한' not in vocabulary"
# 에러가 발생했습니다. "word '화이트' not in vocabulary"
# 에러가 발생했습니다. "word '가격' not in vocabulary"
# 에러가 발생했습니다. "word '구매' not in vocabulary"
# 에러가 발생했습니다. "word '무료' not in vocabulary"
# 에러가 발생했습니다. "word '판매' not in vocabulary"
# 에러가 발생했습니다. "word '할인' not in vocabulary"
# 에러가 발생했습니다. "word '개월' not in vocabulary"
# 에러가 발생했습니다. "word '만원' not in vocabulary"
# 에러가 발생했습니다. "word '얼마' not in vocabulary"
# 에러가 발생했습니다. "word '저렴한' not in vocabulary"
# 에러가 발생했습니다. "word '저렴' not in vocabulary"
# 에러가 발생했습니다. "word '프리미엄' not in vocabulary"
# 에러가 발생했습니다. "word '환율' not in vocabulary"
# 에러가 발생했습니다. "word '노래' not in vocabulary"
# 에러가 발생했습니다. "word '멜론' not in vocabulary"
# 에러가 발생했습니다. "word '이용권' not in vocabulary"
# 에러가 발생했습니다. "word '뮤직' not in vocabulary"
# 에러가 발생했습니다. "word '스트리밍' not in vocabulary"
# 에러가 발생했습니다. "word '신나' not in vocabulary"
# 에러가 발생했습니다. "word '음원' not in vocabulary"
# 에러가 발생했습니다. "word '재생' not in vocabulary"
# 에러가 발생했습니다. "word '지니뮤직' not in vocabulary"
# 에러가 발생했습니다. "word '틀어달라고' not in vocabulary"
# 에러가 발생했습니다. "word '네이버뮤직' not in vocabulary"
# 에러가 발생했습니다. "word '알리' not in vocabulary"
# 에러가 발생했습니다. "word '데이트' not in vocabulary"
# 에러가 발생했습니다. "word '오늘' not in vocabulary"
# 에러가 발생했습니다. "word '뉴스' not in vocabulary"
# 에러가 발생했습니다. "word '아침' not in vocabulary"
# 에러가 발생했습니다. "word '알람' not in vocabulary"
# 에러가 발생했습니다. "word '영어' not in vocabulary"
# 에러가 발생했습니다. "word '콘텐츠' not in vocabulary"
# 에러가 발생했습니다. "word '궁금한' not in vocabulary"
# 에러가 발생했습니다. "word '미세먼지' not in vocabulary"
# 에러가 발생했습니다. "word '설명' not in vocabulary"
# 에러가 발생했습니다. "word '실시간' not in vocabulary"
# 에러가 발생했습니다. "word '영화' not in vocabulary"
# 에러가 발생했습니다. "word '운세' not in vocabulary"
# 에러가 발생했습니다. "word '음식' not in vocabulary"
# 에러가 발생했습니다. "word '추천' not in vocabulary"
# 에러가 발생했습니다. "word '경기' not in vocabulary"
# 에러가 발생했습니다. "word '기사' not in vocabulary"
# 에러가 발생했습니다. "word '답변' not in vocabulary"
# 에러가 발생했습니다. "word '맞추' not in vocabulary"
# 에러가 발생했습니다. "word '오전' not in vocabulary"
# 에러가 발생했습니다. "word '정확' not in vocabulary"
# 에러가 발생했습니다. "word '소리' not in vocabulary"
# 에러가 발생했습니다. "word '음질' not in vocabulary"
# 에러가 발생했습니다. "word '사운드' not in vocabulary"
# 에러가 발생했습니다. "word '들리' not in vocabulary"
# 에러가 발생했습니다. "word '볼륨' not in vocabulary"
# 에러가 발생했습니다. "word '오디오' not in vocabulary"
# 에러가 발생했습니다. "word '최대' not in vocabulary"
# 에러가 발생했습니다. "word '하만카돈' not in vocabulary"
# 에러가 발생했습니다. "word '배터리' not in vocabulary"
# 에러가 발생했습니다. "word '충전' not in vocabulary"
# 에러가 발생했습니다. "word '케이블' not in vocabulary"
# 에러가 발생했습니다. "word '충전기' not in vocabulary"
#      brand category                        words emotion
# 0        0        4                    (누구, 1.0)     999
# 1        0        4    (텔레콤, 0.5504485368728638)     999
# 2        0        4      (캔, 0.4966966509819031)     999
# 3        0        4  (디바이스, 0.44776710867881775)     999
# 4        0        4  (인공지능, 0.44092047214508057)     999
# 5        0        4   (카카오, 0.39573365449905396)     999
# 6        0        4   (통신사, 0.38550931215286255)     999
# 7        0        4    (이동형, 0.3809266686439514)     999
# 8        0        4    (팅커벨, 0.3801175057888031)     999
# 9        0        4     (티맵, 0.3783547878265381)     999
# 10       0        4   (아리야, 0.37572261691093445)     999
# 11       0        4                  (인공지능, 1.0)     999
# 12       0        4    (스피커, 0.5820070505142212)     999
# 13       0        4     (인공, 0.5568007826805115)     999
# 14       0        4     (출시, 0.5007684230804443)     999
# 15       0        4     (지능, 0.4891132116317749)     999
# 16       0        4    (시장, 0.48133406043052673)     999
# 17       0        4     (등장, 0.4792843461036682)     999
# 18       0        4     (최근, 0.4780271649360657)     999
# 19       0        4    (텔레콤, 0.4687230587005615)     999
# 20       0        4   (스마트, 0.46028655767440796)     999
# 21       0        4     (접목, 0.4522610902786255)     999
# 22       0        4                    (지니, 1.0)     999
# 23       0        4      (기, 0.5680243968963623)     999
# 24       0        4    (셋톱박스, 0.541151762008667)     999
# 25       0        4     (올레, 0.5101609826087952)     999
# 26       0        4     (버디, 0.4322454035282135)     999
# 27       0        4    (리모컨, 0.4186777174472809)     999
# 28       0        4     (리모, 0.4069657325744629)     999
# 29       0        4     (키즈, 0.4065176844596863)     999
# ...    ...      ...                          ...     ...
# 6658     5        7      (바, 0.2845657169818878)     999
# 6659     5        7     (화면, 0.2836494445800781)     999
# 6660     5        7   (업데이트, 0.2833811044692993)     999
# 6661     5        7    (음악, 0.28307005763053894)     999
# 6662     5        7    (가능, 0.26628029346466064)     999
# 6663     5        7     (로바, 0.2652297616004944)     999
# 6664     5        7    (제공, 0.24160178005695343)     999
# 6665     5        7    (이용, 0.24074916541576385)     999
# 6666     5        7                    (일정, 1.0)     999
# 6667     5        7     (날씨, 0.5155960321426392)     999
# 6668     5        7    (타이머, 0.5033445358276367)     999
# 6669     5        7    (확인, 0.42353469133377075)     999
# 6670     5        7     (화면, 0.3327483534812927)     999
# 6671     5        7   (블루투스, 0.3096882700920105)     999
# 6672     5        7     (상태, 0.3035675883293152)     999
# 6673     5        7     (기능, 0.2984076738357544)     999
# 6674     5        7     (일상, 0.2877460718154907)     999
# 6675     5        7     (시간, 0.2850714921951294)     999
# 6676     5        7     (저, 0.27744293212890625)     999
# 6677     5        7                    (구글, 1.0)     999
# 6678     5        7      (어시, 0.515968382358551)     999
# 6679     5        7    (스턴트, 0.4639974534511566)     999
# 6680     5        7   (아마존, 0.42874377965927124)     999
# 6681     5        7     (애플, 0.4108523428440094)     999
# 6682     5        7     (비서, 0.3455353379249573)     999
# 6683     5        7    (알렉사, 0.3304799795150757)     999
# 6684     5        7      (월, 0.3036137819290161)     999
# 6685     5        7      (것, 0.2885138988494873)     999
# 6686     5        7   (플랫폼, 0.28735479712486267)     999
# 6687     5        7     (홈, 0.28015565872192383)     999
# [6688 rows x 4 columns]

# %%
print(df10['words'][1])
print(type(df10['words'][1]))
edf10=eval(df10['words'][1])
type(edf10['words'][1])
# Out:
# ('누구', 1.0)
# <class 'str'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-da46e17c25eb> in <module>()
#       2 print(type(df10['words'][1]))
#       3 edf10=eval(df10['words'][1])
# ----> 4 type(edf10['words'][1])
#
# TypeError: tuple indices must be integers or slices, not str

# %%
import pandas as pd
a=pd.read_csv("brand_words_df30.csv")

# %%
a
# Out:
#        Unnamed: 0  brand  category                          words  emotion
# 0               0      0         4                  ('음성인식', 1.0)      999
# 1               1      0         4                    ('누구', 1.0)      999
# 2               2      0         4     ('텔레콤', 0.552889347076416)      999
# 3               3      0         4      ('캔', 0.4822516441345215)      999
# 4               4      0         4   ('디바이스', 0.4468327760696411)      999
# 5               5      0         4  ('인공지능', 0.44569405913352966)      999
# 6               6      0         4    ('통신사', 0.3922707438468933)      999
# 7               7      0         4    ('민트', 0.39162391424179077)      999
# 8               8      0         4     ('형', 0.38874781131744385)      999
# 9               9      0         4   ('이동형', 0.38773155212402344)      999
# 10             10      0         4    ('카카오', 0.3826909363269806)      999
# 11             11      0         4    ('레베카', 0.3749544620513916)      999
# 12             12      0         4   ('아리아', 0.37363675236701965)      999
# 13             13      0         4      ('티탄', 0.373442679643631)      999
# 14             14      0         4     ('진화', 0.3697875738143921)      999
# 15             15      0         4   ('팅커벨', 0.36013346910476685)      999
# 16             16      0         4    ('티맵', 0.35888856649398804)      999
# 17             17      0         4      ('무드', 0.358336478471756)      999
# 18             18      0         4     ('사용', 0.3519017696380615)      999
# 19             19      0         4    ('최초', 0.35184651613235474)      999
# 20             20      0         4     ('소개', 0.3513714671134949)      999
# 21             21      0         4    ('아리야', 0.3495526909828186)      999
# 22             22      0         4     ('한', 0.34876614809036255)      999
# 23             23      0         4     ('흰색', 0.3480631113052368)      999
# 24             24      0         4    ('심플', 0.34399789571762085)      999
# 25             25      0         4  ('크리스탈', 0.34109175205230713)      999
# 26             26      0         4    ('지금', 0.33524468541145325)      999
# 27             27      0         4   ('주식회사', 0.3324592113494873)      999
# 28             28      0         4    ('제품', 0.32940536737442017)      999
# 29             29      0         4   ('에디션', 0.32893723249435425)      999
# ...           ...    ...       ...                            ...      ...
# 19404       19404      5         7     ('년', 0.20666979253292084)      999
# 19405       19405      5         7     ('가능', 0.2039625644683838)      999
# 19406       19406      5         7     ('중', 0.20282486081123352)      999
# 19407       19407      5         7     ('개', 0.20039480924606323)      999
# 19408       19408      5         7                   ('궁금한', 1.0)      999
# 19409       19409      5         7                  ('미세먼지', 1.0)      999
# 19410       19410      5         7                    ('설명', 1.0)      999
# 19411       19411      5         7                   ('실시간', 1.0)      999
# 19412       19412      5         7                    ('영화', 1.0)      999
# 19413       19413      5         7                    ('운세', 1.0)      999
# 19414       19414      5         7                    ('음식', 1.0)      999
# 19415       19415      5         7                    ('추천', 1.0)      999
# 19416       19416      5         7                    ('경기', 1.0)      999
# 19417       19417      5         7                    ('기사', 1.0)      999
# 19418       19418      5         7                    ('답변', 1.0)      999
# 19419       19419      5         7                    ('맞추', 1.0)      999
# 19420       19420      5         7                    ('오전', 1.0)      999
# 19421       19421      5         7                    ('정확', 1.0)      999
# 19422       19422      5         2                    ('소리', 1.0)      999
# 19423       19423      5         2                    ('음질', 1.0)      999
# 19424       19424      5         2                   ('사운드', 1.0)      999
# 19425       19425      5         2                    ('들리', 1.0)      999
# 19426       19426      5         2                    ('볼륨', 1.0)      999
# 19427       19427      5         2                   ('오디오', 1.0)      999
# 19428       19428      5         2                    ('최대', 1.0)      999
# 19429       19429      5         2                  ('하만카돈', 1.0)      999
# 19430       19430      5         3                   ('배터리', 1.0)      999
# 19431       19431      5         3                    ('충전', 1.0)      999
# 19432       19432      5         3                   ('케이블', 1.0)      999
# 19433       19433      5         3                   ('충전기', 1.0)      999
#
# [19434 rows x 5 columns]
